# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)
X, Y = np.meshgrid(x, y)
Z = np.random.random((100, 100))

plt.contourf(X, Y, Z, cmap='Pastel1')
plt.colorbar()
plt.title('Homework1 -- ContourPlot')
plt.xlabel('X')
plt.ylabel('Y')


plt.savefig('HW1ContourPlot.png')
plt.show()

# %%
list1 = [0,30,43,50,10,23,12,3,6,29,100,78,64,3,47]
list2 = [7,38,63,59,108,13,43,87,41,2,10,92,60,62,32]

list_to_array1 = np.array(list1)
list_to_array2 = np.array(list2)

# %%
plt.scatter(list1, list2, color="r")
plt.xlabel('x')
plt.ylabel('y')
plt.title('Homework1 -- ScatterPlot')
plt.savefig('HW1ScatterPlot.png')

# %%
def mathfunc(list1, list2):
    
    added_list = np.add(list1, list2)

    return added_list

# %%
mathfunc(list1, list2)
# Out:
# array([  7,  68, 106, 109, 118,  36,  55,  90,  47,  31, 110, 170, 124,
#         65,  79])
